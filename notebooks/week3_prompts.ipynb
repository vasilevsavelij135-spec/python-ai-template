# %% [markdown]
# <a href="https://colab.research.google.com/github/componavt/python-ai-template/blob/main/notebooks/week3_prompts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Задание 3: Создание визуализаций с помощью DeepSeek
# 📊 Week 3
# ## Ваша задача:
# Создать **минимум 7 различных визуализаций** на основе вашего ноутбука `week2b_read_csv.ipynb`.
#
# **Контекст:** Ноутбук `week2b_read_csv.ipynb` был создан на предыдущей неделе. В нём вы читаете CSV-таблицы, полученные из Викиданных с помощью SPARQL-запросов, и выполняете первичную проверку и поверхностный анализ этих данных. Теперь мы визуализируем эти данные, чтобы найти интересные инсайты.
#
# ---
#
# ## 📋 Как работать:
#
# 1. **Выполните все ячейки** в ноутбуке `week2b_read_csv.ipynb` (меню: Runtime → Run all)
# 2. **Сохраните ноутбук с результатами:**
#    - **Вариант А (GitHub):** Сохраните на GitHub, затем скачайте файл `.ipynb` из репозитория
#    - **Вариант Б (Download):** В Google Colab: File → Download → Download .ipynb
# 3. **Прикрепите файл** в чат DeepSeek (важно: с выводом ячеек, не пустой!)
# 4. **Прогоните ВСЕ 10 промптов ниже** — скопируйте каждый и отправьте в DeepSeek
# 5. **Выберите визуализации:** Из результатов каждого промпта возьмите минимум 1 график (можно все понравившиеся)
# 6. **Скопируйте код** из ответа DeepSeek → вставьте в новую ячейку Colab
# 7. **Запустите** и проверьте результат
#
# **Итого:** Минимум 7 визуализаций (можно больше), выберите самые яркие из 10 промптов.
#
# ---
#
# ## 🎨 Примеры промптов (прогони все 10!):
#
# ### 🌟 Промпт 1: Разведочный анализ
# ```
# Изучи прикреплённый ноутбук с моими данными.
#
# Проведи глубокий анализ данных и создай 5-7 различных визуализаций, которые покажут самое интересное в этих данных.
#
# Требования:
# - Выбери типы графиков сам, исходя из природы данных (примеры: bar, pie, histogram, scatter, box plot, violin plot, heatmap, line chart, treemap, sunburst — но можешь использовать и другие)
# - Используй разнообразные визуализации (не повторяйся)
# - Каждый график должен быть максимально информативным и красивым
# - Размер графиков: figsize=(12, 6) или больше
# - К каждому графику добавь одну строку текста: какой инсайт он показывает
# - Используй профессиональное оформление: заголовки, подписи осей, сетку, легенду
#
# Покажи всю мощь визуализации данных!
# ```
#
# ---
#
# ### 🗺️ Промпт 2: Географические карты (если есть страны или координаты)
# ```
# Данные в прикреплённом ноутбуке.
#
# Если в данных есть информация о странах, регионах или географических координатах — создай географические визуализации.
#
# Требования:
# - Если есть столбец со странами: нарисуй карту мира (choropleth map) с цветовой кодировкой по числовому показателю из данных
# - Используй библиотеку plotly.express, geopandas или folium
# - Если есть координаты (широта, долгота): нанеси точки на карту с размером/цветом пропорциональным какому-то параметру
# - Добавь интерактивность (hover с деталями)
# - Объясни географические паттерны: какие регионы лидируют, есть ли кластеры
#
# Если в данных нет географической информации — скажи об этом и предложи альтернативу.
#
# Покажи данные на карте мира!
# ```
#
# ---
#
# ### 🔥 Промпт 3: Найди скрытые паттерны
# ```
# Данные в прикреплённом ноутбуке.
#
# Найди и визуализируй скрытые паттерны, связи и закономерности в данных.
#
# Требования:
# - Проанализируй, какие переменные могут быть связаны
# - Выбери самый подходящий тип визуализации для каждой связи (heatmap корреляций, scatter, network graph, parallel coordinates, и т.д.)
# - Создай 3-5 графиков, показывающих неожиданные находки
# - Для каждого графика объясни: что интересного ты обнаружил
# - Используй продвинутые техники (кластеризация, корреляции, группировки)
#
# Удиви меня находками в данных!
# ```
#
# ---
#
# ### 🎯 Промпт 4: Сравнительный анализ
# ```
# Изучи данные в ноутбуке.
#
# Создай серию визуализаций для сравнения категорий между собой.
#
# Требования:
# - Сам выбери 2-3 интересные категории для сравнения
# - Используй разные методы сравнения (grouped bar, box plot, violin plot, radar chart, small multiples)
# - Покажи, чем отличаются эти категории по разным параметрам
# - К каждому графику добавь вывод: кто лидер и почему
# - Используй контрастные цвета для наглядности
#
# Сделай сравнение максимально наглядным и убедительным!
# ```
#
# ---
#
# ### 📊 Промпт 5: Временные ряды (если есть даты/годы)
# ```
# Прикреплён ноутбук с данными.
#
# Если в данных есть временная информация (годы, даты, периоды) — создай визуализации эволюции во времени.
#
# Требования:
# - Line chart: покажи, как менялись показатели со временем
# - Area chart или stacked area: если несколько категорий
# - Timeline или Gantt chart: если есть события с датами начала/конца
# - Добавь тренды, сглаживание (moving average), аннотации ключевых точек
# - Объясни: что изменилось, есть ли рост/падение, цикличность
#
# Если временной информации нет — скажи об этом и предложи другой тип анализа.
#
# Покажи эволюцию данных во времени!
# ```
#
# ---
#
# ### 🕸️ Промпт 6: Сетевой граф (если есть связи между объектами)
# ```
# Данные в ноутбуке.
#
# Если в данных есть связи между объектами (например, страны и их города-побратимы, актёры и фильмы, компании и продукты) — создай сетевую визуализацию.
#
# Требования:
# - Используй библиотеку networkx + matplotlib или plotly для интерактивности
# - Размер узлов пропорционален важности (количество связей, значение показателя)
# - Цвет узлов по категориям
# - Покажи только значимые узлы (топ-20), чтобы граф был читаемым
# - Объясни структуру: кто центральные узлы, есть ли кластеры
#
# Если связей нет — скажи об этом и предложи альтернативную иерархическую визуализацию (treemap, sunburst).
#
# Покажи сеть связей!
# ```
#
# ---
#
# ### 💎 Промпт 7: Интерактивные визуализации Plotly
# ```
# Прикреплён ноутбук с данными.
#
# Создай 2-3 интерактивные визуализации с помощью Plotly.
#
# Требования:
# - Выбери типы графиков, которые выигрывают от интерактивности (sunburst, treemap, sankey, 3D scatter, animated bar chart race)
# - Добавь hover-подсказки с деталями
# - Сделай возможность кликать и исследовать данные
# - Если есть временная динамика — создай анимацию (animation_frame)
# - Объясни, какие инсайты открываются благодаря интерактивности
#
# Создай "вау-эффект" для зрителей!
# ```
#
# ---
#
# ### 🧠 Промпт 8: Статистический анализ
# ```
# Данные в прикреплённом ноутбуке.
#
# Проведи статистический анализ с визуализацией.
#
# Требования:
# - Найди корреляции между переменными (heatmap)
# - Определи выбросы (outliers) и визуализируй их (box plot, scatter с выделением)
# - Проведи кластеризацию (если данные подходят) и визуализируй через PCA или t-SNE
# - Покажи распределения и их характеристики (медиана, квартили, мода) через violin plot или histogram с KDE
# - Используй продвинутые графики (pair plot, joint plot)
# - К каждому графику добавь статистическую интерпретацию
#
# Покажи данные глазами статистика!
# ```
#
# ---
#
# ### 🌈 Промпт 9: Креативная визуализация
# ```
# Изучи мой ноутбук с данными.
#
# Создай самые необычные и креативные визуализации для этих данных.
#
# Требования:
# - Используй нестандартные типы графиков (radar chart, parallel coordinates, wordcloud из текстовых полей, alluvial diagram, chord diagram)
# - Экспериментируй с цветами, формами, компоновкой
# - Если стандартные графики не подходят — придумай свой способ визуализации
# - Объясни, почему именно такой способ подачи лучше всего раскрывает данные
# - Сделай визуализации запоминающимися
#
# Разбуди воображение и создай шедевр!
# ```
#
# ---
#
# ### 🎭 Промпт 10: Удиви меня!
# ```
# Изучи мой ноутбук с данными.
#
# Предложи и создай 3 самые яркие и незабываемые визуализации для этих данных.
#
# Требования:
# - Разные типы графиков (не повторяться)
# - От простых к сложным
# - Каждый график должен показывать неожиданный инсайт
# - Используй всю мощь Python-библиотек (matplotlib, seaborn, plotly, networkx, geopandas, folium)
# - Объясни, почему ты выбрал именно эти визуализации и что они открывают
#
# Покажи класс! 🚀
# ```
#
# ---
#
# ## 💡 Советы по работе с DeepSeek:
#
# ### ✅ Если код не работает
# Скопируйте текст ошибки и отправьте DeepSeek:
# ```
# Вот ошибка: [текст ошибки]
# Как исправить?
# ```
#
# ### 🎨 Выбор цветовых палитр
#
# **Matplotlib палитры:** https://matplotlib.org/stable/users/explain/colors/colormaps.html
#
# - **Sequential** (упорядоченные данные): `viridis`, `plasma`, `Blues`, `YlOrRd`
# - **Diverging** (отклонения от среднего): `coolwarm`, `RdYlGn`, `seismic`
# - **Qualitative** (категории): `tab10`, `Set3`, `Paired`
#
# **Seaborn палитры:** https://seaborn.pydata.org/tutorial/color_palettes.html
#
# - **Категориальные**: `deep`, `muted`, `bright`, `pastel`, `dark`
# - **Последовательные**: `rocket`, `mako`, `flare`, `crest`
#
# Пример промпта:
# ```
# Улучши оформление этого графика:
# - Используй цветовую палитру 'viridis'
# - Добавь сетку для удобства чтения
# - Увеличь размеры шрифтов в полтора-два раза
# - Добавь отступы между элементами
# ```
#
# ### 📖 Если непонятен код
# ```
# Объясни этот код построчно простыми словами для новичка
# ```
#
# ### 🎯 Если нужен другой график
# ```
# Хочу показать связь между X и Y, какой график подойдёт лучше всего?
# ```
#
# ### 🔄 Итеративное улучшение
# Не стесняйтесь просить изменить детали в несколько итераций:
# - "Измени цвет на синий"
# - "Добавь значения на столбцы"
# - "Поверни подписи на 45 градусов"
# - "Увеличь размер графика в два раза"
#
# ### 🔍 Проверка данных
# Если DeepSeek использует неправильные названия столбцов:
# ```
# У меня столбцы называются: [перечисли свои точные названия]
# Перепиши код с правильными именами
# ```
#
# ### 📊 Нехватка данных для визуализации
# Если для интересной визуализации не хватает столбцов (например, года, координат, связей между объектами):
# 1. Вернитесь к **SPARQL-запросу** (неделя 1)
# 2. Добавьте нужные свойства из Викиданных:
#    - **P625** — координаты (широта, долгота)
#    - **P3896** — геофигура страны/региона
#    - **P577** — дата публикации
#    - **P580/P582** — дата начала/окончания
#    - **P190** — города-побратимы
#    - **P47** — граничащие страны
#    - **P17** — страна
# 3. Получите обновлённый CSV
# 4. Повторите анализ с расширенными данными
#
# **Пример:** Если хотите нарисовать карту стран, но нет столбца с странами — добавьте в SPARQL:
# ```sparql
# ?item wdt:P17  ?country.         # страна
# ?item wdt:P495 ?countryOfOrigin. # страна производства
# ```
#
# ### 🧐 Оценка инсайтов
# После создания графика спросите себя:
# - **Показывает ли график что-то интересное?** Если инсайт слабый или очевидный — можно удалить график
# - **Понятен ли график новичку?** Если слишком сложно — упростите или добавьте пояснений
# - **Стоит ли включать в финальную работу?** Выбирайте только лучшие визуализации
#
# ### 🗣 Обсуждение с преподавателем
# **Важно:** Не копируйте слепо код и выводы DeepSeek!
#
# Работа проверяется через переписку в Telegram. Если преподаватель укажет на замечания — вы сможете исправить:
# - **Непонятный график** → добавить пояснения или заменить на более наглядный
# - **Слабый инсайт** → найти более интересную закономерность в данных
# - **Ошибки в коде** → исправить и перезапустить
# - **Некрасивое оформление** → улучшить цвета, подписи, размеры
#
# Перед отправкой работы убедитесь:
# - Вы **понимаете**, что показывает каждый график
# - Вы **согласны** с интерпретацией DeepSeek (или можете её улучшить)
# - Вы **готовы объяснить** любую визуализацию, если преподаватель спросит
#
# Простое бездумное копирование затруднит обсуждение. Анализируйте, критикуйте, улучшайте!
#
# ---
#
# ## ✅ Чек-лист перед отправкой работы:
#
# - [ ] Прогнал все 10 промптов
# - [ ] Создал минимум 7 разных визуализаций (выбрал лучшие)
# - [ ] Каждый график имеет заголовок, подписи, легенду
# - [ ] К каждому графику есть одна строка инсайта
# - [ ] Нашёл 3+ интересных находки в данных
# - [ ] Все ячейки запускаются без ошибок
# - [ ] Использовал минимум 2 библиотеки (matplotlib + seaborn/plotly)
# - [ ] Есть хотя бы один "вау-график" (карта, network graph, sunburst, анимация, heatmap, кластеризация или другой продвинутый)
# - [ ] Понимаю каждый график и могу объяснить преподавателю
#
# ---
#
# **Помните:** DeepSeek видит вывод вашего ноутбука — он знает структуру данных, названия столбцов, типы полей. Доверяйте его анализу, но критически оценивайте результаты! 🚀
